# %% [markdown]
# # Pandas Practice Questions

# %% [markdown]
# ### Assignment 1: DataFrame Creation and Indexing
#
# 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.

# %%
import pandas as pd
import numpy as np

data=np.random.randint(1,31,size=(6,4))
df=pd.DataFrame(data=data)
print(df)
df.set_index(0)
# Out:
#     0   1   2   3
# 0  20  16   7   4
# 1  24  27   6   6
# 2  20  15  11  17
# 3  28  26  12   1
# 4  20  24   9  13
# 5  26   7  26  19
#      1   2   3
# 0
# 20  16   7   4
# 24  27   6   6
# 20  15  11  17
# 28  26  12   1
# 20  24   9  13
# 26   7  26  19

# %% [markdown]
# ### Assignment 2: DataFrame Operations
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.

# %%
data=np.random.randint(1,31,size=(5,3))
df=pd.DataFrame(data)
print(df)
df['3']=df[0]*df[1]
# print(df)
print()
print(df)
# Out:
#     0   1   2
# 0  27   9  22
# 1  27  22  23
# 2  10  30  29
# 3  29   8   4
# 4   2   4  13
#
#     0   1   2    3
# 0  27   9  22  243
# 1  27  22  23  594
# 2  10  30  29  300
# 3  29   8   4  232
# 4   2   4  13    8

# %% [markdown]
# 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.

# %%
data=np.random.randint(1,31,size=(3,4))
df=pd.DataFrame(data)
print(df)
print()
print(df.sum(axis=1))
print(df.sum(axis=0))
# Out:
#     0   1   2   3
# 0  22  19   4  12
# 1  24  10  14  30
# 2  29  26  21  21
#
# 0    57
# 1    78
# 2    97
# dtype: int64
# 0    75
# 1    55
# 2    39
# 3    63
# dtype: int64

# %% [markdown]
# ### Assignment 3: Data Cleaning
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.

# %%
df=pd.DataFrame(np.random.randint(1,31,size=(3,5)))
print("Original DataFrame:")
print(df)

print()

df.iloc[1,3]=np.nan
df.iloc[2,4]=np.nan
df.iloc[2,3]=np.nan
print("DataFrame with NaN values:")
print(df)

df.fillna(df.mean(),inplace=True)

print()

print("DataFrame with NaN values filled:")
print(df)
# Out:
# Original DataFrame:
#     0   1   2   3   4
# 0  10  25  26   1  11
# 1   4  24   1  23  24
# 2  29   3  25   6  28
#
# DataFrame with NaN values:
#     0   1   2    3     4
# 0  10  25  26  1.0  11.0
# 1   4  24   1  NaN  24.0
# 2  29   3  25  NaN   NaN
#
# DataFrame with NaN values filled:
#     0   1   2    3     4
# 0  10  25  26  1.0  11.0
# 1   4  24   1  1.0  24.0
# 2  29   3  25  1.0  17.5

# %% [markdown]
# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.

# %%
df=pd.DataFrame(np.random.randint(1,31,size=(6,4)))
print("Original Dataframe:\n",df,"\n")

df.iloc[0,1]=np.nan
df.iloc[1,3]=np.nan
df.iloc[4,2]=np.nan
df.iloc[4,2]=np.nan

print("Before Deleting NaN values:\n",df,"\n")

df.dropna(inplace=True)

print("After Deleting NaN values:\n",df)
# Out:
# Original Dataframe:
#      0   1   2   3
# 0   3  24  30  11
# 1  11  23   2   7
# 2  16  29   8  28
# 3  15   4   4  24
# 4  20  17   2  27
# 5  18  18   7  28
#
# Before Deleting NaN values:
#      0     1     2     3
# 0   3   NaN  30.0  11.0
# 1  11  23.0   2.0   NaN
# 2  16  29.0   8.0  28.0
# 3  15   4.0   4.0  24.0
# 4  20  17.0   NaN  27.0
# 5  18  18.0   7.0  28.0
#
# After Deleting NaN values:
#      0     1    2     3
# 2  16  29.0  8.0  28.0
# 3  15   4.0  4.0  24.0
# 5  18  18.0  7.0  28.0

# %% [markdown]
# ### Assignment 4: Data Aggregation
#
# 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.

# %%
df=pd.DataFrame({'Category':np.random.choice(['A', 'B', 'C'],size=10),'Value':np.random.randint(1,31,size=10)})
print(df)
print()
df=df.groupby('Category')['Value'].agg(['sum','mean'])
print(df)
# Out:
#   Category  Value
# 0        A     23
# 1        A      5
# 2        B      6
# 3        C      5
# 4        A     22
# 5        A      9
# 6        B     28
# 7        B     14
# 8        C     18
# 9        A     24
#
#           sum  mean
# Category
# A          83  16.6
# B          48  16.0
# C          23  11.5

# %% [markdown]
# 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.

# %%
df=pd.DataFrame({'Prouduct': np.random.choice(['S23','S24','S25','S26'],size=10),'Category':np.random.choice(['A','B','C'],size=10),'Sales':np.random.randint(1,101,size=10)})
print(df)
print()
ans=df.groupby('Category')['Sales'].sum()
print(ans)
# Out:
#   Prouduct Category  Sales
# 0      S24        A     31
# 1      S24        C     29
# 2      S26        C     53
# 3      S26        C     59
# 4      S25        C     94
# 5      S24        C     75
# 6      S26        B     62
# 7      S23        A     67
# 8      S24        C     62
# 9      S23        A     40
#
# Category
# A    138
# B     62
# C    372
# Name: Sales, dtype: int32

# %% [markdown]
# ### Assignment 5: Merging DataFrames
#
# 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.

# %%
df1=pd.DataFrame({'Key': ['A', 'B', 'C', 'D'], 'Value1': np.random.randint(1, 100, size=4)})
df2=pd.DataFrame({'Key': ['A', 'B', 'C', 'E'], 'Value2': np.random.randint(1, 100, size=4)})
print("DataFrame 1:")
print(df1)
print("DataFrame 2:")
print(df2)
merged=pd.merge(df1, df2, on='Key')
print("Merged DataFrame:")
print(merged)
# Out:
# DataFrame 1:
#   Key  Value1
# 0   A      93
# 1   B      44
# 2   C      80
# 3   D      22
# DataFrame 2:
#   Key  Value2
# 0   A      16
# 1   B      60
# 2   C      83
# 3   E      20
# Merged DataFrame:
#   Key  Value1  Value2
# 0   A      93      16
# 1   B      44      60
# 2   C      80      83

# %% [markdown]
# 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.

# %%
df1=pd.DataFrame({'A':np.random.randint(1,21,size=3),'B':np.random.randint(1,21,size=3)})
df2=pd.DataFrame({'C':np.random.randint(1,21,size=3),'D':np.random.randint(1,21,size=3)})
print("DataFrame 1:")
print(df1)
print("DataFrame 2:")
print(df2)

print()

row_concatenated_df=pd.concat([df1,df2],axis=0)
print(row_concatenated_df)

print()

col_concatenated_df=pd.concat([df1,df2],axis=1)
print(col_concatenated_df)
# Out:
# DataFrame 1:
#     A   B
# 0   5  10
# 1  12  18
# 2   6   2
# DataFrame 2:
#    C   D
# 0  1  12
# 1  9   4
# 2  3  11
#
#       A     B    C     D
# 0   5.0  10.0  NaN   NaN
# 1  12.0  18.0  NaN   NaN
# 2   6.0   2.0  NaN   NaN
# 0   NaN   NaN  1.0  12.0
# 1   NaN   NaN  9.0   4.0
# 2   NaN   NaN  3.0  11.0
#
#     A   B  C   D
# 0   5  10  1  12
# 1  12  18  9   4
# 2   6   2  3  11

# %% [markdown]
# ### Assignment 6: Time Series Analysis
#
# 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.

# %%
date_rng=pd.date_range(start='2022-01-01',end='2022-12-31',freq='D')
df=pd.DataFrame(date_rng,columns=['date'])
df['data']=np.random.randint(0,100,size=(len(date_rng)))
df.set_index('date',inplace=True)
print(df)

print()

monthly_mean=df.resample('ME').mean()
print("Monthly mean dataframe:\n",monthly_mean)
# Out:
#             data
# date
# 2022-01-01    53
# 2022-01-02    28
# 2022-01-03    75
# 2022-01-04    38
# 2022-01-05    85
# ...          ...
# 2022-12-27    51
# 2022-12-28    17
# 2022-12-29    66
# 2022-12-30    21
# 2022-12-31    39
#
# [365 rows x 1 columns]
#
# Monthly mean dataframe:
#                   data
# date
# 2022-01-31  55.967742
# 2022-02-28  54.428571
# 2022-03-31  42.709677
# 2022-04-30  45.600000
# 2022-05-31  42.322581
# 2022-06-30  49.566667
# 2022-07-31  50.774194
# 2022-08-31  49.032258
# 2022-09-30  57.966667
# 2022-10-31  46.354839
# 2022-11-30  54.966667
# 2022-12-31  52.903226

# %% [markdown]
# 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.

# %%
date_rng=pd.date_range(start='2021-01-01',end='2021-12-31',freq='D')
df=pd.DataFrame(date_rng,columns=['date'])
df['data']=np.random.randint(1,1000,size=len(date_rng))
df.set_index('date', inplace=True)
print(df)
rolling_mean_df=df.rolling(window=7).mean()
print("Rolling mean DataFrame:")
print(rolling_mean_df)
# Out:
#             data
# date
# 2021-01-01   878
# 2021-01-02   203
# 2021-01-03   560
# 2021-01-04   295
# 2021-01-05   177
# ...          ...
# 2021-12-27   715
# 2021-12-28   570
# 2021-12-29   836
# 2021-12-30   581
# 2021-12-31   783
#
# [365 rows x 1 columns]
# Rolling mean DataFrame:
#                   data
# date
# 2021-01-01         NaN
# 2021-01-02         NaN
# 2021-01-03         NaN
# 2021-01-04         NaN
# 2021-01-05         NaN
# ...                ...
# 2021-12-27  580.428571
# 2021-12-28  650.285714
# 2021-12-29  634.571429
# 2021-12-30  686.142857
# 2021-12-31  729.142857
#
# [365 rows x 1 columns]

# %% [markdown]
# ### Assignment 7: MultiIndex DataFrame
#
# 1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.

# %%
arrays=[['A', 'A', 'B', 'B'], ['one', 'two', 'one', 'two']]

index=pd.MultiIndex.from_arrays(arrays, names=('Category', 'SubCategory'))

df=pd.DataFrame(np.random.randint(1, 100, size=(4, 3)), index=index, columns=['Value1', 'Value2', 'Value3'])

print("MultiIndex DataFrame:")
print(df)

print("Indexing at Category 'A':")
print(df.loc['A'])

print("Slicing at Category 'B' and SubCategory 'two':")
print(df.loc[('B', 'two')])
# Out:
# MultiIndex DataFrame:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              60      92      81
#          two              48       1      87
# B        one              53      77      42
#          two              12      38      16
# Indexing at Category 'A':
#              Value1  Value2  Value3
# SubCategory
# one              60      92      81
# two              48       1      87
# Slicing at Category 'B' and SubCategory 'two':
# Value1    12
# Value2    38
# Value3    16
# Name: (B, two), dtype: int32

# %% [markdown]
# 2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.

# %%
arrays = [['A', 'A', 'B', 'B', 'C', 'C'], ['one', 'two', 'one', 'two', 'one', 'two']]

index = pd.MultiIndex.from_arrays(arrays, names=('Category', 'SubCategory'))

df = pd.DataFrame(np.random.randint(1, 100, size=(6, 3)), index=index, columns=['Value1', 'Value2', 'Value3'])

print("MultiIndex DataFrame:")
print(df)

sum_values = df.groupby(['Category', 'SubCategory']).sum()

print("Sum of values:")
print(sum_values)
# Out:
# MultiIndex DataFrame:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              91      76      49
#          two              39      79      22
# B        one              66      80      97
#          two              36      62      68
# C        one              86      48      62
#          two               1      72      80
# Sum of values:
#                       Value1  Value2  Value3
# Category SubCategory
# A        one              91      76      49
#          two              39      79      22
# B        one              66      80      97
#          two              36      62      68
# C        one              86      48      62
#          two               1      72      80
